# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/MyDrive/Colab Notebooks/YOLOv8_Final_Proj/mask/archive.zip" -d "/content/"

# %%
# installing package to work with yolov8
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 24.3/166.8 GB disk)

# %%
# Checking the size of images and displaying them
import numpy as np
import cv2
# Image shape in Training
image = cv2.imread('/content/train/train/images/5e353e347af50726986e84c0.jpeg')
height = np.size(image, 0)
width = np.size(image, 1)
print ("shape of the training image {}, {}".format(height, width))

# Image shape in validation
image = cv2.imread('/content/valid/valid/images/maksssksksss103.png')
height = np.size(image, 0)
width = np.size(image, 1)
print ("shape of the validation image {}, {}".format(height, width))
# Out:
# shape of the training image 667, 1000
# shape of the validation image 300, 400

# %%
# dispying with different width
from IPython.display import Image 
Image(filename='/content/train/train/images/5e353e347af50726986e84c0.jpeg', width=300)

# %%
#To modify yam file,writetemplate function needs to be called.
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# I will write the contents of the cell to a file
# %%writefile /content/face_mask_detection.yaml 

# Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2, ..]
path: /content/ # dataset root dir
train: train/train/images/ # train images (relative to 'path')
val: valid/valid/images/ # val images (relative to 'path')
test: test/test/images/ # test images (optional)

# number of classes
nc: 3

# class names
#names: ['0', '1', '2']
names: [ 'no_mask', 'mask','improper_mask']  # class names
# Out:
# Writing /content/face_mask_detection.yaml

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/content/face_mask_detection.yaml", epochs=25, imgsz=640)  #default batch=16
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 198MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8n.yaml, data=/content/face_mask_detection.yaml, epochs=25, patience=50, batch=16, imgsz=640, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=False, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|██████████| 755k/755k [00:00<00:00, 47.7MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.Detect                [3, [64, 128, 256]]
# Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /content/train/train/labels... 990 images, 0 backgrounds, 0 corrupt: 100%|██████████| 990/990 [00:01<00:00, 770.54it/s]
# train: New cache created: /content/train/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/valid/valid/labels... 294 images, 0 backgrounds, 0 corrupt: 100%|██████████| 294/294 [00:00<00:00, 995.52it/s]
# val: New cache created: /content/valid/valid/labels.cache
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      4.86G      1.761      2.878       1.47        144        640: 100%|██████████| 62/62 [00:46<00:00,  1.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:07<00:00,  1.41it/s]
#                    all        294       1473      0.614      0.183       0.23      0.127
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      6.82G      1.432      1.428      1.202        105        640: 100%|██████████| 62/62 [00:37<00:00,  1.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:05<00:00,  1.85it/s]
#                    all        294       1473      0.588      0.387      0.422      0.233
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      6.82G      1.397      1.226      1.144        112        640: 100%|██████████| 62/62 [00:36<00:00,  1.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.01it/s]
#                    all        294       1473      0.805      0.399      0.416      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      6.82G      1.356      1.125      1.117        118        640: 100%|██████████| 62/62 [00:36<00:00,  1.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.08it/s]
#                    all        294       1473      0.818      0.443      0.465      0.247
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      6.82G      1.332      1.052      1.097        161        640: 100%|██████████| 62/62 [00:40<00:00,  1.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:05<00:00,  1.89it/s]
#                    all        294       1473      0.556      0.493      0.494      0.273
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      6.82G      1.287     0.9795      1.079        139        640: 100%|██████████| 62/62 [00:36<00:00,  1.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:05<00:00,  1.98it/s]
#                    all        294       1473      0.454      0.511      0.484      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25      6.82G      1.314     0.9482      1.083        106        640: 100%|██████████| 62/62 [00:36<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.07it/s]
#                    all        294       1473      0.646       0.49      0.468      0.258
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25      6.82G      1.258     0.9021      1.059        145        640: 100%|██████████| 62/62 [00:36<00:00,  1.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.18it/s]
#                    all        294       1473      0.484      0.451      0.433      0.241
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      6.82G      1.244     0.8506       1.06        108        640: 100%|██████████| 62/62 [00:38<00:00,  1.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.17it/s]
#                    all        294       1473      0.502      0.574      0.506      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25      6.82G       1.24     0.8405      1.055         94        640: 100%|██████████| 62/62 [00:38<00:00,  1.60it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.10it/s]
#                    all        294       1473      0.473      0.507      0.477       0.26
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25      6.82G      1.232     0.8275      1.046        103        640: 100%|██████████| 62/62 [00:39<00:00,  1.57it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.11it/s]
#                    all        294       1473      0.593      0.535      0.512      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25      6.82G      1.223     0.7963      1.042        149        640: 100%|██████████| 62/62 [00:39<00:00,  1.58it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.12it/s]
#                    all        294       1473      0.729      0.504      0.536      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25      6.82G      1.188     0.7612      1.032        126        640: 100%|██████████| 62/62 [00:36<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.13it/s]
#                    all        294       1473      0.543      0.543      0.537      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25      6.82G      1.175     0.7524      1.024        115        640: 100%|██████████| 62/62 [00:36<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.13it/s]
#                    all        294       1473        0.6       0.63      0.535      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      6.82G      1.172     0.7294      1.029         77        640: 100%|██████████| 62/62 [00:40<00:00,  1.54it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.14it/s]
#                    all        294       1473      0.622      0.594      0.544      0.322
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25      6.82G      1.174     0.7647      1.033         61        640: 100%|██████████| 62/62 [00:19<00:00,  3.22it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.07it/s]
#                    all        294       1473      0.621      0.581      0.529      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25      6.82G      1.144     0.7229      1.018         44        640: 100%|██████████| 62/62 [00:15<00:00,  3.98it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.13it/s]
#                    all        294       1473      0.566      0.589      0.506      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25      6.82G      1.137     0.7021      1.016         58        640: 100%|██████████| 62/62 [00:15<00:00,  3.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:05<00:00,  1.98it/s]
#                    all        294       1473      0.505      0.591      0.509      0.292
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      6.82G      1.119      0.687      1.017        120        640: 100%|██████████| 62/62 [00:15<00:00,  3.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.16it/s]
#                    all        294       1473      0.639      0.626      0.558      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25      6.82G      1.117     0.6684      1.007         68        640: 100%|██████████| 62/62 [00:16<00:00,  3.85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:05<00:00,  1.99it/s]
#                    all        294       1473      0.569      0.584      0.529      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      6.82G      1.097     0.6492      1.008         53        640: 100%|██████████| 62/62 [00:15<00:00,  3.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.13it/s]
#                    all        294       1473      0.593      0.647       0.55      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25      6.82G       1.08     0.6382      0.988         81        640: 100%|██████████| 62/62 [00:15<00:00,  3.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:05<00:00,  1.85it/s]
#                    all        294       1473       0.65      0.582      0.553      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25      6.82G      1.066     0.6276     0.9884         63        640: 100%|██████████| 62/62 [00:15<00:00,  3.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:04<00:00,  2.14it/s]
#                    all        294       1473      0.669      0.632      0.573      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25      6.82G      1.043     0.6107     0.9831         42        640: 100%|██████████| 62/62 [00:15<00:00,  3.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:05<00:00,  1.86it/s]
#                    all        294       1473      0.645      0.662      0.578      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      6.82G      1.042     0.6067     0.9764         24        640: 100%|██████████| 62/62 [00:15<00:00,  3.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
#                    all        294       1473      0.596      0.649      0.549      0.327
#
# 25 epochs completed in 0.248 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 6.2MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:08<00:00,  1.23it/s]
#                    all        294       1473      0.644      0.662      0.577      0.345
#                no_mask        294        225       0.77      0.658      0.672      0.377
#                   mask        294       1235       0.81       0.79      0.801       0.48
#          improper_mask        294         13      0.352      0.538      0.259      0.178
# Speed: 0.9ms pre-process, 2.0ms inference, 0.0ms loss, 6.6ms post-process per image
# Results saved to runs/detect/train

# %%
results = model.val()  # evaluate model performance on the validation set
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/valid/valid/labels.cache... 294 images, 0 backgrounds, 0 corrupt: 100%|██████████| 294/294 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.35it/s]
#                    all        294       1473      0.623      0.668      0.566      0.338
#                no_mask        294        225      0.737      0.667      0.671      0.378
#                   mask        294       1235      0.801      0.799      0.803       0.48
#          improper_mask        294         13       0.33      0.538      0.226      0.157
# Speed: 0.7ms pre-process, 5.1ms inference, 0.0ms loss, 4.1ms post-process per image

# %%
# dislaying metrics for train data
from IPython.display import Image
from IPython.display import display
x = Image(filename='runs/detect/train/F1_curve.png') 
y = Image(filename='runs/detect/train/PR_curve.png') 
z = Image(filename='runs/detect/train/confusion_matrix.png') 
display(x, y,z)

# %%
# loading the trianed model
model = YOLO("runs/detect/train/weights/best.pt")  # load a custom model

# %%
# testing the model on a video
# results = model("/content/drive/MyDrive/datasets/mask_dataset/mask_testing.mp4") 

#---------------解決跑出NotImplementedError: A UTF-8 locale is required. Got ANSI_X3.4-1968--------------------
import locale
locale.getpreferredencoding = lambda: "UTF-8"
#--------------------------------------------------------------------------

# !yolo task=detect mode=predict model="runs/detect/train/weights/best.pt" source="/content/test/test/images" save=True
# Out:
# 2023-05-26 15:17:12.174376: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# image 1/141 /content/test/test/images/NUZZHAB7IMI6VHQQW44IVOMBHU.jpg: 448x640 1 mask, 61.4ms
# image 2/141 /content/test/test/images/OIP7vZHgEGheRWy-R6I19P3TQHaE8.jpg: 448x640 4 no_masks, 7.8ms
# image 3/141 /content/test/test/images/P0000100005637_3_37742.jpg: 640x640 1 mask, 9.8ms
# image 4/141 /content/test/test/images/PA-49784209-1024x684.jpg: 448x640 3 masks, 7.3ms
# image 5/141 /content/test/test/images/PHOTriZgIKIgsnNLdBJG75vj200203_1000x2000.jpg: 448x640 1 no_mask, 4 masks, 6.1ms
# image 6/141 /content/test/test/images/PRI_129079114_1580299603.195.jpg: 512x640 2 masks, 53.9ms
# image 7/141 /content/test/test/images/Pakistan-China-coronavirus-92news.jpg: 416x640 7 masks, 1 improper_mask, 52.3ms
# image 8/141 /content/test/test/images/Persone.jpg: 384x640 1 no_mask, 20 masks, 52.3ms
# image 9/141 /content/test/test/images/PhotoGrid_1580452532909.jpg: 352x640 11 masks, 61.4ms
# image 10/141 /content/test/test/images/maksssksksss354.png: 480x640 22 masks, 52.9ms
# image 11/141 /content/test/test/images/maksssksksss355.png: 640x512 1 mask, 54.5ms
# image 12/141 /content/test/test/images/maksssksksss356.png: 640x512 1 mask, 6.0ms
# image 13/141 /content/test/test/images/maksssksksss357.png: 384x640 1 mask, 6.5ms
# image 14/141 /content/test/test/images/maksssksksss358.png: 480x640 4 masks, 6.7ms
# image 15/141 /content/test/test/images/maksssksksss359.png: 384x640 1 no_mask, 19 masks, 6.5ms
# image 16/141 /content/test/test/images/maksssksksss360.png: 448x640 1 mask, 8.2ms
# image 17/141 /content/test/test/images/maksssksksss361.png: 416x640 3 no_masks, 1 mask, 6.5ms
# image 18/141 /content/test/test/images/maksssksksss362.png: 448x640 3 masks, 6.6ms
# image 19/141 /content/test/test/images/maksssksksss363.png: 320x640 9 masks, 53.5ms
# image 20/141 /content/test/test/images/maksssksksss364.png: 448x640 3 masks, 6.8ms
# image 21/141 /content/test/test/images/maksssksksss365.png: 384x640 2 no_masks, 2 masks, 6.5ms
# image 22/141 /content/test/test/images/maksssksksss385.png: 416x640 4 no_masks, 1 mask, 6.7ms
# image 23/141 /content/test/test/images/maksssksksss386.png: 448x640 6 masks, 6.6ms
# image 24/141 /content/test/test/images/maksssksksss387.png: 384x640 5 masks, 1 improper_mask, 6.7ms
# image 25/141 /content/test/test/images/maksssksksss388.png: 384x640 7 no_masks, 9 masks, 1 improper_mask, 6.8ms
# image 26/141 /content/test/test/images/maksssksksss389.png: 480x640 2 no_masks, 10 masks, 6.7ms
# image 27/141 /content/test/test/images/maksssksksss390.png: 480x640 6 masks, 6.0ms
# image 28/141 /content/test/test/images/maksssksksss391.png: 448x640 1 no_mask, 4 masks, 6.8ms
# image 29/141 /content/test/test/images/maksssksksss392.png: 448x640 1 mask, 6.0ms
# image 30/141 /content/test/test/images/maksssksksss393.png: 640x640 2 masks, 7.9ms
# image 31/141 /content/test/test/images/maksssksksss394.png: 352x640 1 mask, 6.9ms
# image 32/141 /content/test/test/images/maksssksksss395.png: 448x640 1 mask, 7.6ms
# image 33/141 /content/test/test/images/maksssksksss396.png: 480x640 1 no_mask, 5 masks, 9.7ms
# image 34/141 /content/test/test/images/maksssksksss397.png: 384x640 6 masks, 8.0ms
# image 35/141 /content/test/test/images/maksssksksss398.png: 544x640 1 mask, 52.8ms
# image 36/141 /content/test/test/images/maksssksksss399.png: 448x640 1 no_mask, 7 masks, 7.0ms
# image 37/141 /content/test/test/images/maksssksksss475.png: 448x640 2 no_masks, 5 masks, 6.0ms
# image 38/141 /content/test/test/images/maksssksksss476.png: 448x640 2 no_masks, 5 masks, 6.0ms
# image 39/141 /content/test/test/images/maksssksksss477.png: 448x640 5 no_masks, 7 masks, 6.4ms
# image 40/141 /content/test/test/images/maksssksksss478.png: 640x640 2 masks, 8.2ms
# image 41/141 /content/test/test/images/maksssksksss479.png: 640x512 1 mask, 6.7ms
# image 42/141 /content/test/test/images/maksssksksss480.png: 640x512 1 mask, 6.0ms
# image 43/141 /content/test/test/images/maksssksksss481.png: 448x640 6 masks, 6.6ms
# image 44/141 /content/test/test/images/maksssksksss482.png: 640x512 1 no_mask, 6.7ms
# image 45/141 /content/test/test/images/maksssksksss483.png: 448x640 1 no_mask, 4 masks, 6.6ms
# image 46/141 /content/test/test/images/maksssksksss484.png: 640x448 3 improper_masks, 55.3ms
# image 47/141 /content/test/test/images/maksssksksss485.png: 640x512 1 mask, 6.7ms
# image 48/141 /content/test/test/images/maksssksksss486.png: 352x640 1 no_mask, 4 masks, 6.7ms
# image 49/141 /content/test/test/images/maksssksksss487.png: 448x640 1 no_mask, 4 masks, 8.9ms
# image 50/141 /content/test/test/images/maksssksksss488.png: 448x640 2 masks, 6.0ms
# image 51/141 /content/test/test/images/maksssksksss489.png: 352x640 5 no_masks, 2 masks, 6.8ms
# image 52/141 /content/test/test/images/maksssksksss490.png: 640x512 1 mask, 6.7ms
# image 53/141 /content/test/test/images/maksssksksss550.png: 640x640 1 mask, 7.9ms
# image 54/141 /content/test/test/images/maksssksksss701.png: 640x512 1 no_mask, 6.6ms
# image 55/141 /content/test/test/images/maksssksksss702.png: 352x640 1 no_mask, 10 masks, 9.0ms
# image 56/141 /content/test/test/images/maksssksksss703.png: 448x640 5 no_masks, 7 masks, 7.8ms
# image 57/141 /content/test/test/images/maksssksksss704.png: 448x640 8 masks, 6.1ms
# image 58/141 /content/test/test/images/maksssksksss705.png: 384x640 21 masks, 6.6ms
# image 59/141 /content/test/test/images/maksssksksss706.png: 448x640 23 masks, 7.7ms
# image 60/141 /content/test/test/images/maksssksksss707.png: 640x512 1 mask, 7.0ms
# image 61/141 /content/test/test/images/maksssksksss708.png: 384x640 5 masks, 7.6ms
# image 62/141 /content/test/test/images/maksssksksss709.png: 640x512 1 mask, 6.6ms
# image 63/141 /content/test/test/images/maksssksksss710.png: 320x640 1 no_mask, 2 masks, 7.7ms
# image 64/141 /content/test/test/images/maksssksksss711.png: 480x640 8 masks, 6.7ms
# image 65/141 /content/test/test/images/maksssksksss712.png: 640x512 2 masks, 6.7ms
# image 66/141 /content/test/test/images/maksssksksss713.png: 480x640 1 mask, 7.2ms
# image 67/141 /content/test/test/images/maksssksksss714.png: 480x640 4 masks, 6.7ms
# image 68/141 /content/test/test/images/maksssksksss715.png: 640x448 1 no_mask, 1 mask, 6.7ms
# image 69/141 /content/test/test/images/maksssksksss716.png: 640x512 1 no_mask, 6.8ms
# image 70/141 /content/test/test/images/maksssksksss717.png: 384x640 1 no_mask, 3 masks, 6.7ms
# image 71/141 /content/test/test/images/maksssksksss718.png: 448x640 1 no_mask, 7 masks, 1 improper_mask, 6.9ms
# image 72/141 /content/test/test/images/maksssksksss719.png: 384x640 6 masks, 7.6ms
# image 73/141 /content/test/test/images/maksssksksss730.png: 448x640 3 masks, 6.6ms
# image 74/141 /content/test/test/images/maksssksksss731.png: 640x640 2 masks, 7.9ms
# image 75/141 /content/test/test/images/maksssksksss732.png: 448x640 2 no_masks, 6 masks, 6.7ms
# image 76/141 /content/test/test/images/maksssksksss733.png: 480x640 1 mask, 7.4ms
# image 77/141 /content/test/test/images/maksssksksss734.png: 384x640 1 mask, 7.4ms
# image 78/141 /content/test/test/images/maksssksksss735.png: 384x640 5 no_masks, 5 masks, 6.0ms
# image 79/141 /content/test/test/images/maksssksksss736.png: 640x448 2 masks, 7.9ms
# image 80/141 /content/test/test/images/maksssksksss737.png: 384x640 6 masks, 1 improper_mask, 10.3ms
# image 81/141 /content/test/test/images/maksssksksss738.png: 448x640 2 masks, 6.6ms
# image 82/141 /content/test/test/images/maksssksksss739.png: 384x640 1 mask, 6.9ms
# image 83/141 /content/test/test/images/maksssksksss740.png: 448x640 2 masks, 6.6ms
# image 84/141 /content/test/test/images/maksssksksss741.png: 640x448 1 mask, 1 improper_mask, 7.3ms
# image 85/141 /content/test/test/images/maksssksksss742.png: 640x512 1 mask, 6.6ms
# image 86/141 /content/test/test/images/maksssksksss743.png: 640x512 1 mask, 6.0ms
# image 87/141 /content/test/test/images/maksssksksss744.png: 384x640 2 masks, 6.7ms
# image 88/141 /content/test/test/images/maksssksksss745.png: 640x512 1 mask, 6.8ms
# image 89/141 /content/test/test/images/maksssksksss746.png: 640x512 1 mask, 6.0ms
# image 90/141 /content/test/test/images/maksssksksss747.png: 640x512 1 mask, 6.0ms
# image 91/141 /content/test/test/images/maksssksksss748.png: 384x640 1 mask, 1 improper_mask, 6.8ms
# image 92/141 /content/test/test/images/maksssksksss749.png: 640x416 2 masks, 52.9ms
# image 93/141 /content/test/test/images/maksssksksss750.png: 448x640 6 no_masks, 7.3ms
# image 94/141 /content/test/test/images/maksssksksss751.png: 448x640 1 no_mask, 2 masks, 6.9ms
# image 95/141 /content/test/test/images/maksssksksss752.png: 384x640 9 masks, 7.1ms
# image 96/141 /content/test/test/images/nouveau-virus-en-chine-la-ville-de-wuhan-mise-en-quarantaine-1.jpg: 320x640 1 no_mask, 8 masks, 6.7ms
# image 97/141 /content/test/test/images/nq50003q8p6q8n72p7o.jpg: 640x448 2 no_masks, 1 mask, 7.2ms
# image 98/141 /content/test/test/images/nq50003q8p707o0p586.jpg: 640x448 3 no_masks, 6.2ms
# image 99/141 /content/test/test/images/nqn000p326n081sq0np.jpg: 640x448 4 no_masks, 6.4ms
# image 100/141 /content/test/test/images/nqn000p326o7525q707.jpg: 640x448 3 no_masks, 6.3ms
# image 101/141 /content/test/test/images/nyu-coronavirus.jpg: 448x640 6 no_masks, 2 masks, 9.6ms
# image 102/141 /content/test/test/images/nz_srilanka_280120.jpg: 448x640 1 no_mask, 3 masks, 6.1ms
# image 103/141 /content/test/test/images/observerbd.com_1580560442.jpg: 448x640 4 masks, 6.1ms
# image 104/141 /content/test/test/images/oms-declara-emergencia-internacional-por-coronavirus-ap (1).jpg: 384x640 6 masks, 1 improper_mask, 6.8ms
# image 105/141 /content/test/test/images/oms-declara-emergencia-internacional-por-coronavirus-ap.jpg: 384x640 6 masks, 1 improper_mask, 6.1ms
# image 106/141 /content/test/test/images/organizacion-preocupacion-potencial-virus-propague.jpg: 416x640 17 masks, 7.0ms
# image 107/141 /content/test/test/images/ows_158334350017224.jpg: 544x640 7 no_masks, 2 masks, 7.8ms
# image 108/141 /content/test/test/images/oxford-face-mask-neoprene-svart.jpg: 640x512 1 mask, 6.7ms
# image 109/141 /content/test/test/images/p410009sn4po8p82746.jpg: 640x448 3 masks, 7.2ms
# image 110/141 /content/test/test/images/p41000n445r5595258q.jpg: 640x448 1 mask, 6.1ms
# image 111/141 /content/test/test/images/p600000670oq209288n.jpg: 640x448 1 mask, 7.7ms
# image 112/141 /content/test/test/images/p60000067206nr1o3nq.jpg: 640x448 1 mask, 5.9ms
# image 113/141 /content/test/test/images/p61000068153229q475.jpg: 640x448 1 no_mask, 2 masks, 5.9ms
# image 114/141 /content/test/test/images/pb-140116-chinasmog-01_f0be38db4f1769172f4a0fa2e888d565.fit-2000w.jpg: 448x640 1 no_mask, 4 masks, 7.3ms
# image 115/141 /content/test/test/images/people-standing-at-bus-stop-waiting-A8K95K(1).jpg: 480x640 3 no_masks, 6.9ms
# image 116/141 /content/test/test/images/people-standing-at-bus-stop-waiting-A8K95K.jpg: 480x640 3 no_masks, 6.2ms
# image 117/141 /content/test/test/images/people-waiting-at-a-bus-stop-in-london-uk-AKBC3M(1).jpg: 480x640 7 no_masks, 6.2ms
# image 118/141 /content/test/test/images/people-waiting-at-a-bus-stop-in-london-uk-AKBC3M.jpg: 480x640 7 no_masks, 6.1ms
# image 119/141 /content/test/test/images/people-waiting-at-a-bus-stop-marrakech-morocco-africa-CPPBR8(1).jpg: 480x640 6 no_masks, 6.2ms
# image 120/141 /content/test/test/images/people-waiting-at-a-bus-stop-marrakech-morocco-africa-CPPBR8.jpg: 480x640 6 no_masks, 6.8ms
# image 121/141 /content/test/test/images/people-waiting-at-bus-sto_450(1).jpg: 448x640 5 no_masks, 6.7ms
# image 122/141 /content/test/test/images/people-waiting-at-bus-sto_450.jpg: 448x640 5 no_masks, 6.1ms
# image 123/141 /content/test/test/images/people-waiting-at-bus-stop-ashgabat-turkmenistan-B4X2H9(1).jpg: 512x640 7 no_masks, 6.9ms
# image 124/141 /content/test/test/images/people-waiting-at-bus-stop-ashgabat-turkmenistan-B4X2H9.jpg: 512x640 7 no_masks, 6.4ms
# image 125/141 /content/test/test/images/people-waiting-for-bus-at-a-bus-stop-porto-portugal-europe-C7BJEE.jpg: 480x640 10 no_masks, 1 mask, 7.0ms
# image 126/141 /content/test/test/images/photo (1).jpeg: 384x640 1 mask, 7.0ms
# image 127/141 /content/test/test/images/photo (2).jpeg: 480x640 1 mask, 6.8ms
# image 128/141 /content/test/test/images/photo (3).jpeg: 384x640 2 no_masks, 3 masks, 6.5ms
# image 129/141 /content/test/test/images/photo (4).jpeg: 640x480 1 mask, 51.3ms
# image 130/141 /content/test/test/images/photo (5).jpeg: 480x640 1 mask, 7.0ms
# image 131/141 /content/test/test/images/photo_0001_2020-02-04_F4IA3IB100AN0001NOS.jpg: 448x640 6 masks, 6.9ms
# image 132/141 /content/test/test/images/photo_l.jpg: 480x640 1 no_mask, 6 masks, 7.3ms
# image 133/141 /content/test/test/images/phpM5suKS.jpg: 608x640 3 no_masks, 3 masks, 53.3ms
# image 134/141 /content/test/test/images/phppaNXxb.jpg: 416x640 3 no_masks, 5 masks, 6.8ms
# image 135/141 /content/test/test/images/pic_list_out_2285.jpg: 640x640 4 masks, 8.0ms
# image 136/141 /content/test/test/images/pjecDNMmCUQmbDoJx1fdqolnfHtpsfFK8jTA2Ng0wNg.jpeg: 448x640 3 no_masks, 5 masks, 7.3ms
# image 137/141 /content/test/test/images/pollution-mask-CE5HYF.jpg: 480x640 2 masks, 6.9ms
# image 138/141 /content/test/test/images/purchase-reauisition-5de4d0f99c77d.jpg: 448x640 2 no_masks, 8 masks, 7.3ms
# image 139/141 /content/test/test/images/r0_0_800_600_w1200_h678_fmax.jpg: 480x640 3 no_masks, 3 masks, 6.9ms
# image 140/141 /content/test/test/images/r1p00017o80q34s9781.jpg: 640x448 1 no_mask, 1 improper_mask, 6.6ms
# image 141/141 /content/test/test/images/r1p00017o82psp0o0or.jpg: 640x448 1 improper_mask, 6.0ms
# Speed: 0.5ms pre-process, 11.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# !yolo task=detect mode=predict model="runs/detect/train/weights/best.pt" source="/content/TEST1.mp4" save=True
# Out:
# 2023-05-26 15:17:26.860741: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/cfg/__init__.py", line 249, in entrypoint
#     getattr(model, mode)(verbose=True, **overrides)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 146, in predict
#     return self.predictor(source=source, stream=stream, verbose=verbose)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/predictor.py", line 158, in __call__
#     return list(self.stream_inference(source, model, verbose))  # merge list of Result into one
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/predictor.py", line 173, in stream_inference
#     self.setup_source(source)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/predictor.py", line 139, in setup_source
#     self.dataset = LoadImages(source,
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/data/dataloaders/stream_loaders.py", line 172, in __init__
#     raise FileNotFoundError(f'{p} does not exist')
# FileNotFoundError: /content/TEST1.mp4 does not exist

# %% [markdown]
# ### ?開啟鏡頭?

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.22.4)

# %%
import cv2

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("無法開啟鏡頭。")
else:
    print("鏡頭已成功開啟。")

cap.release()
# Out:
# 無法開啟鏡頭。

# %%
# !apt-get update
# !apt-get install -y libsm6 libxext6 libxrender-dev

import cv2
from google.colab import output

try:
    cap = cv2.VideoCapture(0)
    cap.release()
    output.clear()
    print("鏡頭許可權已設定正確。")
except Exception as e:
    print("無法設定鏡頭許可權：", str(e))
# Out:
# 鏡頭許可權已設定正確。

# %%
# import dependencies
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from google.colab.patches import cv2_imshow
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# %%
# initialize the Haar Cascade face detection model
face_cascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))

# %%
# JavaScript to properly create our live video stream using our webcam as input
def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    
    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data

# %%
# # start streaming video from webcam
# video_stream()
# # label for video
# label_html = 'Capturing...'
# # initialze bounding box to empty
# bbox = ''
# count = 0 
# while True:
#     js_reply = video_frame(label_html, bbox)
#     if not js_reply:
#         break

#     # convert JS response to OpenCV Image
#     img = js_to_image(js_reply["img"])

#     # create transparent overlay for bounding box
#     bbox_array = np.zeros([480,640,4], dtype=np.uint8)

#     # grayscale image for face detection
#     gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

#     # get face region coordinates
#     faces = face_cascade.detectMultiScale(gray)
#     # get face bounding box for overlay
#     for (x,y,w,h) in faces:
#       bbox_array = cv2.rectangle(bbox_array,(x,y),(x+w,y+h),(255,0,0),2)

#     bbox_array[:,:,3] = (bbox_array.max(axis = 2) > 0 ).astype(int) * 255
#     # convert overlay of bbox into bytes
#     bbox_bytes = bbox_to_bytes(bbox_array)
#     # update bbox so next frame gets new overlay
#     bbox = bbox_bytes
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-22-6ab59feaad8b> in <cell line: 8>()
#       7 count = 0
#       8 while True:
# ----> 9     js_reply = video_frame(label_html, bbox)
#      10     if not js_reply:
#      11         break
#
# <ipython-input-21-a05efe86d862> in video_frame(label, bbox)
#     132
#     133 def video_frame(label, bbox):
# --> 134   data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
#     135   return data
#
# /usr/local/lib/python3.10/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result, timeout_sec)
#      38   if ignore_result:
#      39     return
# ---> 40   return _message.read_reply_from_input(request_id, timeout_sec)
#      41
#      42
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: Cell has no view

# %%
# !pip install supervision==0.2.1
