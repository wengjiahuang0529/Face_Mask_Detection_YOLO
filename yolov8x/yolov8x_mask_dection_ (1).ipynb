# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -uq "/content/drive/MyDrive/Colab Notebooks/YOLOv8_Final_Proj/mask/archive.zip" -d "/content/"

# %%
# installing package to work with yolov8
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 24.3/166.8 GB disk)

# %%
# Checking the size of images and displaying them
import numpy as np
import cv2
# Image shape in Training
image = cv2.imread('/content/train/train/images/5e353e347af50726986e84c0.jpeg')
height = np.size(image, 0)
width = np.size(image, 1)
print ("shape of the training image {}, {}".format(height, width))

# Image shape in validation
image = cv2.imread('/content/valid/valid/images/maksssksksss103.png')
height = np.size(image, 0)
width = np.size(image, 1)
print ("shape of the validation image {}, {}".format(height, width))
# Out:
# shape of the training image 667, 1000
# shape of the validation image 300, 400

# %%
# dispying with different width
from IPython.display import Image 
Image(filename='/content/train/train/images/5e353e347af50726986e84c0.jpeg', width=300)

# %%
#To modify yam file,writetemplate function needs to be called.
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# I will write the contents of the cell to a file
# %%writefile /content/face_mask_detection.yaml 

# Train/val/test sets as 1) dir: path/to/imgs, 2) file: path/to/imgs.txt, or 3) list: [path/to/imgs1, path/to/imgs2, ..]
path: /content/ # dataset root dir
train: train/train/images/ # train images (relative to 'path')
val: valid/valid/images/ # val images (relative to 'path')
test: test/test/images/ # test images (optional)

# number of classes
nc: 3

# class names
#names: ['0', '1', '2']
names: [ 'no_mask', 'mask','improper_mask']  # class names
# Out:
# Writing /content/face_mask_detection.yaml

# %%
# from google.colab import files
# files.download('/content/runs/detect/train/weights/best.pt')

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov8x.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/content/face_mask_detection.yaml", epochs=25, imgsz=640,batch=8)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8x.pt to yolov8x.pt...
# 100%|██████████| 131M/131M [00:07<00:00, 19.3MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8x.yaml, data=/content/face_mask_detection.yaml, epochs=25, patience=50, batch=8, imgsz=640, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=False, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=False, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0010078125, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3, cfg=None, v5loader=False, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|██████████| 755k/755k [00:00<00:00, 149MB/s]
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.Conv                  [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.Conv                  [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.C2f                   [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.Conv                  [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.C2f                   [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.Conv                  [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.C2f                   [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.Conv                  [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.C2f                   [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.SPPF                  [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.C2f                   [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.C2f                   [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.Conv                  [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.C2f                   [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.Conv                  [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.C2f                   [1280, 640, 3]
#  22        [15, 18, 21]  1   8720857  ultralytics.nn.modules.Detect                [3, [320, 640, 640]]
# Model summary: 365 layers, 68155497 parameters, 68155481 gradients, 258.1 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0010078125), 103 bias
# train: Scanning /content/train/train/labels... 990 images, 0 backgrounds, 0 corrupt: 100%|██████████| 990/990 [00:01<00:00, 753.02it/s]
# train: New cache created: /content/train/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/valid/valid/labels... 294 images, 0 backgrounds, 0 corrupt: 100%|██████████| 294/294 [00:00<00:00, 961.47it/s]
# val: New cache created: /content/valid/valid/labels.cache
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      9.85G       1.75       1.86      1.469         91        640: 100%|██████████| 124/124 [01:21<00:00,  1.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:09<00:00,  2.05it/s]
#                    all        294       1473       0.82      0.439      0.469      0.252
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      10.8G       1.31     0.9504      1.138         86        640: 100%|██████████| 124/124 [01:16<00:00,  1.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.35it/s]
#                    all        294       1473      0.482      0.551      0.498      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      10.8G      1.315     0.9424      1.112         77        640: 100%|██████████| 124/124 [01:15<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.22it/s]
#                    all        294       1473      0.523      0.506      0.484      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      10.8G      1.305     0.8784      1.102         53        640: 100%|██████████| 124/124 [01:15<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.32it/s]
#                    all        294       1473      0.497      0.523      0.493      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      10.8G      1.307      0.755      1.101         66        640: 100%|██████████| 124/124 [01:15<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.20it/s]
#                    all        294       1473      0.562      0.595      0.508      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      10.8G      1.304     0.7878      1.108         28        640: 100%|██████████| 124/124 [01:14<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:07<00:00,  2.40it/s]
#                    all        294       1473      0.536      0.589      0.522      0.295
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25      10.8G      1.268     0.7557      1.088        233        640: 100%|██████████| 124/124 [01:15<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.37it/s]
#                    all        294       1473      0.565      0.568      0.511      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25      10.8G      1.274     0.7451      1.094         80        640: 100%|██████████| 124/124 [01:14<00:00,  1.68it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.23it/s]
#                    all        294       1473      0.562      0.643      0.555      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      10.8G      1.237     0.7197      1.097         37        640: 100%|██████████| 124/124 [01:15<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.24it/s]
#                    all        294       1473      0.619      0.602      0.562      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25      10.8G       1.23     0.7126      1.113         90        640: 100%|██████████| 124/124 [01:15<00:00,  1.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:07<00:00,  2.42it/s]
#                    all        294       1473      0.548      0.664      0.568      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25      10.8G      1.203     0.6744      1.089        103        640: 100%|██████████| 124/124 [01:14<00:00,  1.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:07<00:00,  2.40it/s]
#                    all        294       1473      0.578       0.61      0.575       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25      10.8G        1.2     0.6881      1.071         60        640: 100%|██████████| 124/124 [01:14<00:00,  1.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.37it/s]
#                    all        294       1473      0.626      0.702      0.572      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25      10.8G      1.196     0.6648      1.052         39        640: 100%|██████████| 124/124 [01:14<00:00,  1.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.36it/s]
#                    all        294       1473      0.618      0.663       0.57      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25      10.8G      1.175     0.6573      1.054         57        640: 100%|██████████| 124/124 [01:14<00:00,  1.66it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.25it/s]
#                    all        294       1473      0.595      0.667       0.57      0.353
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      10.8G      1.156     0.6287      1.058         48        640: 100%|██████████| 124/124 [01:16<00:00,  1.62it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.28it/s]
#                    all        294       1473      0.559       0.64      0.567      0.358
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25      10.8G      1.096     0.5753      1.103         10        640: 100%|██████████| 124/124 [01:13<00:00,  1.69it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:07<00:00,  2.40it/s]
#                    all        294       1473      0.626      0.619      0.576      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25      10.8G      1.093     0.5712      1.075         28        640: 100%|██████████| 124/124 [01:11<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.22it/s]
#                    all        294       1473      0.608      0.621      0.565      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25      10.8G      1.098     0.5532      1.082         16        640: 100%|██████████| 124/124 [01:11<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.22it/s]
#                    all        294       1473      0.569      0.663      0.547      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      10.8G       1.08     0.5543      1.065         58        640: 100%|██████████| 124/124 [01:11<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:07<00:00,  2.41it/s]
#                    all        294       1473      0.582      0.641       0.58      0.357
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25      10.8G       1.06     0.5352       1.07         20        640: 100%|██████████| 124/124 [01:11<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:07<00:00,  2.40it/s]
#                    all        294       1473      0.555      0.656      0.568      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      10.8G      1.035     0.5187      1.054         26        640: 100%|██████████| 124/124 [01:11<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.25it/s]
#                    all        294       1473      0.593       0.71      0.584      0.356
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25      10.8G      1.022     0.4981       1.03         46        640: 100%|██████████| 124/124 [01:12<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.31it/s]
#                    all        294       1473      0.607      0.712      0.617      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25      10.8G     0.9972     0.4866      1.028         19        640: 100%|██████████| 124/124 [01:11<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:07<00:00,  2.41it/s]
#                    all        294       1473      0.574      0.617      0.599      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25      10.8G     0.9835      0.466      1.026         12        640: 100%|██████████| 124/124 [01:12<00:00,  1.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:08<00:00,  2.37it/s]
#                    all        294       1473      0.572      0.695      0.569      0.364
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      10.8G     0.9632     0.4496      1.011         12        640: 100%|██████████| 124/124 [01:11<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:12<00:00,  1.58it/s]
#                    all        294       1473       0.59       0.68      0.586      0.372
#
# 25 epochs completed in 0.601 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 136.7MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 136.7MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68126457 parameters, 0 gradients, 257.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:11<00:00,  1.67it/s]
#                    all        294       1473      0.608      0.713      0.617      0.381
#                no_mask        294        225       0.72      0.776      0.732      0.424
#                   mask        294       1235      0.787       0.83      0.827      0.516
#          improper_mask        294         13      0.316      0.534      0.292      0.203
# Speed: 0.4ms pre-process, 16.7ms inference, 0.0ms loss, 3.7ms post-process per image
# Results saved to runs/detect/train

# %%
results = model.val()  # evaluate model performance on the validation set
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68126457 parameters, 0 gradients, 257.4 GFLOPs
# val: Scanning /content/valid/valid/labels.cache... 294 images, 0 backgrounds, 0 corrupt: 100%|██████████| 294/294 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 37/37 [00:16<00:00,  2.27it/s]
#                    all        294       1473      0.609      0.713      0.622      0.384
#                no_mask        294        225      0.721      0.773      0.731      0.425
#                   mask        294       1235      0.791      0.832       0.83      0.516
#          improper_mask        294         13      0.316      0.532      0.306      0.212
# Speed: 0.2ms pre-process, 46.0ms inference, 0.0ms loss, 1.5ms post-process per image

# %%
# dislaying metrics for train data
from IPython.display import Image
from IPython.display import display
x = Image(filename='runs/detect/train/F1_curve.png') 
y = Image(filename='runs/detect/train/PR_curve.png') 
z = Image(filename='runs/detect/train/confusion_matrix.png') 
display(x, y,z)

# %%
# loading the trianed model
model = YOLO("runs/detect/train/weights/best.pt")  # load a custom model

# %%
# testing the model on a video
# results = model("/content/drive/MyDrive/datasets/mask_dataset/mask_testing.mp4") 

#---------------解決跑出NotImplementedError: A UTF-8 locale is required. Got ANSI_X3.4-1968--------------------
import locale
locale.getpreferredencoding = lambda: "UTF-8"
#--------------------------------------------------------------------------

# !yolo task=detect mode=predict model="runs/detect/train/weights/best.pt" source="/content/test/test/images" save=True
# Out:
# 2023-05-26 16:57:11.393881: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68126457 parameters, 0 gradients, 257.4 GFLOPs
# image 1/141 /content/test/test/images/NUZZHAB7IMI6VHQQW44IVOMBHU.jpg: 448x640 1 no_mask, 1 mask, 65.6ms
# image 2/141 /content/test/test/images/OIP7vZHgEGheRWy-R6I19P3TQHaE8.jpg: 448x640 4 no_masks, 53.5ms
# image 3/141 /content/test/test/images/P0000100005637_3_37742.jpg: 640x640 1 mask, 74.0ms
# image 4/141 /content/test/test/images/PA-49784209-1024x684.jpg: 448x640 1 mask, 37.3ms
# image 5/141 /content/test/test/images/PHOTriZgIKIgsnNLdBJG75vj200203_1000x2000.jpg: 448x640 4 masks, 37.8ms
# image 6/141 /content/test/test/images/PRI_129079114_1580299603.195.jpg: 512x640 2 masks, 63.7ms
# image 7/141 /content/test/test/images/Pakistan-China-coronavirus-92news.jpg: 416x640 9 masks, 63.8ms
# image 8/141 /content/test/test/images/Persone.jpg: 384x640 1 no_mask, 20 masks, 65.1ms
# image 9/141 /content/test/test/images/PhotoGrid_1580452532909.jpg: 352x640 11 masks, 70.8ms
# image 10/141 /content/test/test/images/maksssksksss354.png: 480x640 28 masks, 65.1ms
# image 11/141 /content/test/test/images/maksssksksss355.png: 640x512 1 mask, 65.6ms
# image 12/141 /content/test/test/images/maksssksksss356.png: 640x512 1 mask, 37.9ms
# image 13/141 /content/test/test/images/maksssksksss357.png: 384x640 1 mask, 34.7ms
# image 14/141 /content/test/test/images/maksssksksss358.png: 480x640 4 masks, 38.8ms
# image 15/141 /content/test/test/images/maksssksksss359.png: 384x640 1 no_mask, 19 masks, 34.3ms
# image 16/141 /content/test/test/images/maksssksksss360.png: 448x640 1 mask, 36.4ms
# image 17/141 /content/test/test/images/maksssksksss361.png: 416x640 2 no_masks, 1 mask, 37.3ms
# image 18/141 /content/test/test/images/maksssksksss362.png: 448x640 3 masks, 38.3ms
# image 19/141 /content/test/test/images/maksssksksss363.png: 320x640 6 masks, 66.2ms
# image 20/141 /content/test/test/images/maksssksksss364.png: 448x640 3 masks, 34.1ms
# image 21/141 /content/test/test/images/maksssksksss365.png: 384x640 2 no_masks, 2 masks, 34.9ms
# image 22/141 /content/test/test/images/maksssksksss385.png: 416x640 2 no_masks, 1 mask, 36.7ms
# image 23/141 /content/test/test/images/maksssksksss386.png: 448x640 6 masks, 39.7ms
# image 24/141 /content/test/test/images/maksssksksss387.png: 384x640 1 no_mask, 4 masks, 1 improper_mask, 34.1ms
# image 25/141 /content/test/test/images/maksssksksss388.png: 384x640 8 no_masks, 9 masks, 1 improper_mask, 32.7ms
# image 26/141 /content/test/test/images/maksssksksss389.png: 480x640 2 no_masks, 9 masks, 38.4ms
# image 27/141 /content/test/test/images/maksssksksss390.png: 480x640 6 masks, 38.9ms
# image 28/141 /content/test/test/images/maksssksksss391.png: 448x640 4 masks, 39.5ms
# image 29/141 /content/test/test/images/maksssksksss392.png: 448x640 1 mask, 38.3ms
# image 30/141 /content/test/test/images/maksssksksss393.png: 640x640 2 masks, 53.4ms
# image 31/141 /content/test/test/images/maksssksksss394.png: 352x640 1 mask, 35.6ms
# image 32/141 /content/test/test/images/maksssksksss395.png: 448x640 1 mask, 38.1ms
# image 33/141 /content/test/test/images/maksssksksss396.png: 480x640 1 no_mask, 5 masks, 39.8ms
# image 34/141 /content/test/test/images/maksssksksss397.png: 384x640 4 masks, 33.7ms
# image 35/141 /content/test/test/images/maksssksksss398.png: 544x640 1 mask, 64.0ms
# image 36/141 /content/test/test/images/maksssksksss399.png: 448x640 1 no_mask, 7 masks, 36.9ms
# image 37/141 /content/test/test/images/maksssksksss475.png: 448x640 1 no_mask, 5 masks, 37.8ms
# image 38/141 /content/test/test/images/maksssksksss476.png: 448x640 2 no_masks, 5 masks, 37.6ms
# image 39/141 /content/test/test/images/maksssksksss477.png: 448x640 6 no_masks, 7 masks, 37.7ms
# image 40/141 /content/test/test/images/maksssksksss478.png: 640x640 2 masks, 53.9ms
# image 41/141 /content/test/test/images/maksssksksss479.png: 640x512 1 mask, 42.2ms
# image 42/141 /content/test/test/images/maksssksksss480.png: 640x512 1 mask, 40.8ms
# image 43/141 /content/test/test/images/maksssksksss481.png: 448x640 6 masks, 39.8ms
# image 44/141 /content/test/test/images/maksssksksss482.png: 640x512 1 no_mask, 43.2ms
# image 45/141 /content/test/test/images/maksssksksss483.png: 448x640 1 no_mask, 3 masks, 37.9ms
# image 46/141 /content/test/test/images/maksssksksss484.png: 640x448 1 improper_mask, 65.8ms
# image 47/141 /content/test/test/images/maksssksksss485.png: 640x512 1 mask, 37.7ms
# image 48/141 /content/test/test/images/maksssksksss486.png: 352x640 2 no_masks, 4 masks, 34.9ms
# image 49/141 /content/test/test/images/maksssksksss487.png: 448x640 1 no_mask, 4 masks, 36.5ms
# image 50/141 /content/test/test/images/maksssksksss488.png: 448x640 2 masks, 37.6ms
# image 51/141 /content/test/test/images/maksssksksss489.png: 352x640 4 no_masks, 2 masks, 33.6ms
# image 52/141 /content/test/test/images/maksssksksss490.png: 640x512 1 mask, 41.7ms
# image 53/141 /content/test/test/images/maksssksksss550.png: 640x640 1 mask, 60.2ms
# image 54/141 /content/test/test/images/maksssksksss701.png: 640x512 1 no_mask, 44.4ms
# image 55/141 /content/test/test/images/maksssksksss702.png: 352x640 3 no_masks, 9 masks, 33.6ms
# image 56/141 /content/test/test/images/maksssksksss703.png: 448x640 4 no_masks, 6 masks, 36.5ms
# image 57/141 /content/test/test/images/maksssksksss704.png: 448x640 8 masks, 37.7ms
# image 58/141 /content/test/test/images/maksssksksss705.png: 384x640 1 no_mask, 17 masks, 34.2ms
# image 59/141 /content/test/test/images/maksssksksss706.png: 448x640 24 masks, 36.8ms
# image 60/141 /content/test/test/images/maksssksksss707.png: 640x512 1 mask, 41.0ms
# image 61/141 /content/test/test/images/maksssksksss708.png: 384x640 4 masks, 34.5ms
# image 62/141 /content/test/test/images/maksssksksss709.png: 640x512 1 mask, 41.3ms
# image 63/141 /content/test/test/images/maksssksksss710.png: 320x640 1 no_mask, 2 masks, 32.3ms
# image 64/141 /content/test/test/images/maksssksksss711.png: 480x640 8 masks, 39.1ms
# image 65/141 /content/test/test/images/maksssksksss712.png: 640x512 1 mask, 44.0ms
# image 66/141 /content/test/test/images/maksssksksss713.png: 480x640 1 mask, 40.8ms
# image 67/141 /content/test/test/images/maksssksksss714.png: 480x640 4 masks, 39.3ms
# image 68/141 /content/test/test/images/maksssksksss715.png: 640x448 2 no_masks, 1 mask, 38.7ms
# image 69/141 /content/test/test/images/maksssksksss716.png: 640x512 1 no_mask, 42.3ms
# image 70/141 /content/test/test/images/maksssksksss717.png: 384x640 1 no_mask, 3 masks, 1 improper_mask, 36.0ms
# image 71/141 /content/test/test/images/maksssksksss718.png: 448x640 1 no_mask, 8 masks, 1 improper_mask, 36.5ms
# image 72/141 /content/test/test/images/maksssksksss719.png: 384x640 1 no_mask, 7 masks, 33.6ms
# image 73/141 /content/test/test/images/maksssksksss730.png: 448x640 3 masks, 37.0ms
# image 74/141 /content/test/test/images/maksssksksss731.png: 640x640 2 masks, 54.9ms
# image 75/141 /content/test/test/images/maksssksksss732.png: 448x640 2 no_masks, 7 masks, 38.4ms
# image 76/141 /content/test/test/images/maksssksksss733.png: 480x640 1 mask, 38.6ms
# image 77/141 /content/test/test/images/maksssksksss734.png: 384x640 1 mask, 35.3ms
# image 78/141 /content/test/test/images/maksssksksss735.png: 384x640 6 no_masks, 5 masks, 32.7ms
# image 79/141 /content/test/test/images/maksssksksss736.png: 640x448 1 no_mask, 2 masks, 36.8ms
# image 80/141 /content/test/test/images/maksssksksss737.png: 384x640 6 masks, 1 improper_mask, 34.1ms
# image 81/141 /content/test/test/images/maksssksksss738.png: 448x640 2 masks, 37.2ms
# image 82/141 /content/test/test/images/maksssksksss739.png: 384x640 1 mask, 35.0ms
# image 83/141 /content/test/test/images/maksssksksss740.png: 448x640 2 masks, 36.7ms
# image 84/141 /content/test/test/images/maksssksksss741.png: 640x448 1 mask, 1 improper_mask, 38.6ms
# image 85/141 /content/test/test/images/maksssksksss742.png: 640x512 1 mask, 41.9ms
# image 86/141 /content/test/test/images/maksssksksss743.png: 640x512 1 mask, 41.6ms
# image 87/141 /content/test/test/images/maksssksksss744.png: 384x640 2 masks, 33.6ms
# image 88/141 /content/test/test/images/maksssksksss745.png: 640x512 1 mask, 41.1ms
# image 89/141 /content/test/test/images/maksssksksss746.png: 640x512 1 mask, 41.5ms
# image 90/141 /content/test/test/images/maksssksksss747.png: 640x512 1 mask, 40.9ms
# image 91/141 /content/test/test/images/maksssksksss748.png: 384x640 1 mask, 33.8ms
# image 92/141 /content/test/test/images/maksssksksss749.png: 640x416 2 masks, 64.3ms
# image 93/141 /content/test/test/images/maksssksksss750.png: 448x640 7 no_masks, 35.9ms
# image 94/141 /content/test/test/images/maksssksksss751.png: 448x640 1 no_mask, 3 masks, 37.9ms
# image 95/141 /content/test/test/images/maksssksksss752.png: 384x640 11 masks, 34.2ms
# image 96/141 /content/test/test/images/nouveau-virus-en-chine-la-ville-de-wuhan-mise-en-quarantaine-1.jpg: 320x640 1 no_mask, 9 masks, 29.9ms
# image 97/141 /content/test/test/images/nq50003q8p6q8n72p7o.jpg: 640x448 2 no_masks, 36.3ms
# image 98/141 /content/test/test/images/nq50003q8p707o0p586.jpg: 640x448 3 no_masks, 39.0ms
# image 99/141 /content/test/test/images/nqn000p326n081sq0np.jpg: 640x448 4 no_masks, 37.5ms
# image 100/141 /content/test/test/images/nqn000p326o7525q707.jpg: 640x448 1 no_mask, 37.6ms
# image 101/141 /content/test/test/images/nyu-coronavirus.jpg: 448x640 6 no_masks, 3 masks, 35.5ms
# image 102/141 /content/test/test/images/nz_srilanka_280120.jpg: 448x640 1 no_mask, 3 masks, 34.4ms
# image 103/141 /content/test/test/images/observerbd.com_1580560442.jpg: 448x640 4 masks, 36.3ms
# image 104/141 /content/test/test/images/oms-declara-emergencia-internacional-por-coronavirus-ap (1).jpg: 384x640 6 masks, 1 improper_mask, 32.8ms
# image 105/141 /content/test/test/images/oms-declara-emergencia-internacional-por-coronavirus-ap.jpg: 384x640 6 masks, 1 improper_mask, 29.6ms
# image 106/141 /content/test/test/images/organizacion-preocupacion-potencial-virus-propague.jpg: 416x640 15 masks, 35.5ms
# image 107/141 /content/test/test/images/ows_158334350017224.jpg: 544x640 7 no_masks, 2 masks, 47.0ms
# image 108/141 /content/test/test/images/oxford-face-mask-neoprene-svart.jpg: 640x512 1 mask, 42.0ms
# image 109/141 /content/test/test/images/p410009sn4po8p82746.jpg: 640x448 3 masks, 42.4ms
# image 110/141 /content/test/test/images/p41000n445r5595258q.jpg: 640x448 1 mask, 37.4ms
# image 111/141 /content/test/test/images/p600000670oq209288n.jpg: 640x448 1 mask, 38.6ms
# image 112/141 /content/test/test/images/p60000067206nr1o3nq.jpg: 640x448 1 no_mask, 1 mask, 37.3ms
# image 113/141 /content/test/test/images/p61000068153229q475.jpg: 640x448 1 no_mask, 2 masks, 37.1ms
# image 114/141 /content/test/test/images/pb-140116-chinasmog-01_f0be38db4f1769172f4a0fa2e888d565.fit-2000w.jpg: 448x640 1 no_mask, 3 masks, 35.6ms
# image 115/141 /content/test/test/images/people-standing-at-bus-stop-waiting-A8K95K(1).jpg: 480x640 4 no_masks, 37.2ms
# image 116/141 /content/test/test/images/people-standing-at-bus-stop-waiting-A8K95K.jpg: 480x640 4 no_masks, 36.2ms
# image 117/141 /content/test/test/images/people-waiting-at-a-bus-stop-in-london-uk-AKBC3M(1).jpg: 480x640 6 no_masks, 1 mask, 36.9ms
# image 118/141 /content/test/test/images/people-waiting-at-a-bus-stop-in-london-uk-AKBC3M.jpg: 480x640 6 no_masks, 1 mask, 39.6ms
# image 119/141 /content/test/test/images/people-waiting-at-a-bus-stop-marrakech-morocco-africa-CPPBR8(1).jpg: 480x640 9 no_masks, 38.0ms
# image 120/141 /content/test/test/images/people-waiting-at-a-bus-stop-marrakech-morocco-africa-CPPBR8.jpg: 480x640 9 no_masks, 37.2ms
# image 121/141 /content/test/test/images/people-waiting-at-bus-sto_450(1).jpg: 448x640 6 no_masks, 35.9ms
# image 122/141 /content/test/test/images/people-waiting-at-bus-sto_450.jpg: 448x640 6 no_masks, 40.5ms
# image 123/141 /content/test/test/images/people-waiting-at-bus-stop-ashgabat-turkmenistan-B4X2H9(1).jpg: 512x640 7 no_masks, 41.0ms
# image 124/141 /content/test/test/images/people-waiting-at-bus-stop-ashgabat-turkmenistan-B4X2H9.jpg: 512x640 7 no_masks, 38.3ms
# image 125/141 /content/test/test/images/people-waiting-for-bus-at-a-bus-stop-porto-portugal-europe-C7BJEE.jpg: 480x640 10 no_masks, 37.0ms
# image 126/141 /content/test/test/images/photo (1).jpeg: 384x640 1 mask, 31.2ms
# image 127/141 /content/test/test/images/photo (2).jpeg: 480x640 1 mask, 37.8ms
# image 128/141 /content/test/test/images/photo (3).jpeg: 384x640 2 no_masks, 1 mask, 34.7ms
# image 129/141 /content/test/test/images/photo (4).jpeg: 640x480 1 mask, 64.3ms
# image 130/141 /content/test/test/images/photo (5).jpeg: 480x640 1 no_mask, 1 mask, 39.2ms
# image 131/141 /content/test/test/images/photo_0001_2020-02-04_F4IA3IB100AN0001NOS.jpg: 448x640 6 masks, 38.4ms
# image 132/141 /content/test/test/images/photo_l.jpg: 480x640 1 no_mask, 6 masks, 40.1ms
# image 133/141 /content/test/test/images/phpM5suKS.jpg: 608x640 3 no_masks, 3 masks, 64.8ms
# image 134/141 /content/test/test/images/phppaNXxb.jpg: 416x640 3 no_masks, 5 masks, 36.4ms
# image 135/141 /content/test/test/images/pic_list_out_2285.jpg: 640x640 4 masks, 54.5ms
# image 136/141 /content/test/test/images/pjecDNMmCUQmbDoJx1fdqolnfHtpsfFK8jTA2Ng0wNg.jpeg: 448x640 2 no_masks, 5 masks, 34.8ms
# image 137/141 /content/test/test/images/pollution-mask-CE5HYF.jpg: 480x640 3 masks, 37.1ms
# image 138/141 /content/test/test/images/purchase-reauisition-5de4d0f99c77d.jpg: 448x640 1 no_mask, 6 masks, 35.1ms
# image 139/141 /content/test/test/images/r0_0_800_600_w1200_h678_fmax.jpg: 480x640 3 no_masks, 4 masks, 36.6ms
# image 140/141 /content/test/test/images/r1p00017o80q34s9781.jpg: 640x448 1 no_mask, 1 improper_mask, 39.1ms
# image 141/141 /content/test/test/images/r1p00017o82psp0o0or.jpg: 640x448 1 improper_mask, 34.5ms
# Speed: 0.4ms pre-process, 41.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
# !yolo task=detect mode=predict model="runs/detect/train/weights/best.pt" source="/content/TEST1.mp4" save=True
# Out:
# 2023-05-26 16:57:31.420968: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68126457 parameters, 0 gradients, 257.4 GFLOPs
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/cfg/__init__.py", line 249, in entrypoint
#     getattr(model, mode)(verbose=True, **overrides)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 146, in predict
#     return self.predictor(source=source, stream=stream, verbose=verbose)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/predictor.py", line 158, in __call__
#     return list(self.stream_inference(source, model, verbose))  # merge list of Result into one
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/predictor.py", line 173, in stream_inference
#     self.setup_source(source)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/predictor.py", line 139, in setup_source
#     self.dataset = LoadImages(source,
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/data/dataloaders/stream_loaders.py", line 172, in __init__
#     raise FileNotFoundError(f'{p} does not exist')
# FileNotFoundError: /content/TEST1.mp4 does not exist
# Sentry is attempting to send 1 pending events
# Waiting up to 2 seconds
# Press Ctrl-C to quit

# %% [markdown]
# ### ?開啟鏡頭?

# %%
# !pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.22.4)

# %%
import cv2

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("無法開啟鏡頭。")
else:
    print("鏡頭已成功開啟。")

cap.release()
# Out:
# 無法開啟鏡頭。

# %%
# !apt-get update
# !apt-get install -y libsm6 libxext6 libxrender-dev

import cv2
from google.colab import output

try:
    cap = cv2.VideoCapture(0)
    cap.release()
    output.clear()
    print("鏡頭許可權已設定正確。")
except Exception as e:
    print("無法設定鏡頭許可權：", str(e))
# Out:
# 鏡頭許可權已設定正確。

# %%
# import dependencies
from IPython.display import display, Javascript, Image
from google.colab.output import eval_js
from google.colab.patches import cv2_imshow
from base64 import b64decode, b64encode
import cv2
import numpy as np
import PIL
import io
import html
import time
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# %%
# initialize the Haar Cascade face detection model
face_cascade = cv2.CascadeClassifier(cv2.samples.findFile(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'))

# %%
# JavaScript to properly create our live video stream using our webcam as input
def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    
    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'When finished, click here or on the video to stop this demo</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data

# %%
# # start streaming video from webcam
# video_stream()
# # label for video
# label_html = 'Capturing...'
# # initialze bounding box to empty
# bbox = ''
# count = 0 
# while True:
#     js_reply = video_frame(label_html, bbox)
#     if not js_reply:
#         break

#     # convert JS response to OpenCV Image
#     img = js_to_image(js_reply["img"])

#     # create transparent overlay for bounding box
#     bbox_array = np.zeros([480,640,4], dtype=np.uint8)

#     # grayscale image for face detection
#     gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

#     # get face region coordinates
#     faces = face_cascade.detectMultiScale(gray)
#     # get face bounding box for overlay
#     for (x,y,w,h) in faces:
#       bbox_array = cv2.rectangle(bbox_array,(x,y),(x+w,y+h),(255,0,0),2)

#     bbox_array[:,:,3] = (bbox_array.max(axis = 2) > 0 ).astype(int) * 255
#     # convert overlay of bbox into bytes
#     bbox_bytes = bbox_to_bytes(bbox_array)
#     # update bbox so next frame gets new overlay
#     bbox = bbox_bytes

# %%
# !pip install supervision==0.2.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting supervision==0.2.1
#   Downloading supervision-0.2.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.1) (1.22.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.1) (4.7.0.72)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from supervision==0.2.1) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.1) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.1) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.1) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.1) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.1) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.2.1) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->supervision==0.2.1) (1.16.0)
# Installing collected packages: supervision
# Successfully installed supervision-0.2.1
